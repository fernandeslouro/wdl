# %%
import pandas as pd

# %% [markdown]
# # Provided Data

# %%
# !wget https://wdl-data.fra1.digitaloceanspaces.com/pse/outdoor_inventory.zip -q

# %%
# !unzip outdoor_inventory.zip
# Out:
# Archive:  outdoor_inventory.zip
#   inflating: Outdoor_Inventory_AV.shx
#   inflating: __MACOSX/._Outdoor_Inventory_AV.shx
#   inflating: Outdoor_Inventory_AV.shp
#   inflating: __MACOSX/._Outdoor_Inventory_AV.shp
#   inflating: Outdoor_Inventory_AV.qpj
#   inflating: __MACOSX/._Outdoor_Inventory_AV.qpj
#   inflating: Outdoor_Inventory_AV.prj
#   inflating: __MACOSX/._Outdoor_Inventory_AV.prj
#   inflating: Outdoor_Inventory_AV.dbf
#   inflating: __MACOSX/._Outdoor_Inventory_AV.dbf
#   inflating: Outdoor_Inventory_AV.cpg
#   inflating: __MACOSX/._Outdoor_Inventory_AV.cpg

# %%
ine = pd.read_csv('http://www.ine.pt/ngt_server/attachfileu.jsp?look_parentBoui=165404348&att_display=n&att_download=y', encoding='Latin-1')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-7-3bce9bf94f74> in <module>
# ----> 1 ine = pd.read_csv('http://www.ine.pt/ngt_server/attachfileu.jsp?look_parentBoui=165404348&att_display=n&att_download=y', encoding='Latin-1')
#
# ...
