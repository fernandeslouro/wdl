# %% [markdown]
# **senior_tim**: Database with the daily average of senior citizens travelling on road network links based on one year, between April 2019 and March 2020.
# **busroutes**: Identification of road segments that are part of the different bus routes.

# %% [markdown]
# **Goals**: To understand the senior citizens' mobility patterns and their characteristics: We aim to provide better conditions of mobility for our senior citizens, giving them the same opportunities to arrive at their points of interest with affordable and accessible public transport.
# **Outcome**: A general model to design an integrated transportation service for the senior population, or, an integrated transportation service for senior population proposal for one city.

# %%
import pandas as pd
import fiona
import matplotlib.pyplot as plt

# %%
senior_tim = pd.read_csv('https://wdl-data.fra1.digitaloceanspaces.com/pse/Senior_TIM_v1.txt',
                                 encoding = "ISO-8859-1",
                                sep='|')
busroutes = pd.read_csv('https://wdl-data.fra1.digitaloceanspaces.com/pse/BusRoutes.txt',
                                 encoding = "ISO-8859-1",
                                sep='|')
seniors_df = pd.merge(senior_tim, busroutes, on = ['linkid'], how = 'outer')

# %% [markdown]
#  - O merge tem 184603 entradas
#  - Há len(seniors_df[pd.isnull(seniors_df.IDRoute)])=100098 entradas sem IDRoute (deslocações sem ser de autocarro)?
#  - Há 167 busroutes diferentes (incluindo nan)
#  - 4 districts of origin: Lisboa,  Setúbal, Porto, Aveiro
#  - 2 regions of origin - 'R1 - AM Lisboa, 'R2 - AM Porto'
#  - 24 counties of origin

# %%
len(concelhos_dict['Aveiro'])
# Out:
# 10

# %%
for shp in concelhos_shapes:
    if shp['properties']['NAME_2']=='Aveiro':
        print(shp['geometry']['coordinates'][5][1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-105-839ce3281aa1> in <module>
#       1 for shp in concelhos_shapes:
#       2     if shp['properties']['NAME_2']=='Aveiro':
# ----> 3         print(shp['geometry']['coordinates'][5][1])
#
# IndexError: list index out of range

# %%
asa = fiona.open("/home/primity/terras/gadm36_PRT_shp/gadm36_PRT_3.shp")

# %% [raw]
# asa[0]

# %%
for shp in asa:
    if shp['properties']['TYPE_3'] != 'Parish':
        print(shp)

# %%
concelhos_shapes = fiona.open("/home/primity/terras/gadm36_PRT_shp/gadm36_PRT_2.shp")

concelhos_dict = {}
for shp in concelhos_shapes:
    concelhos_dict[shp['properties']['NAME_2']] = shp['geometry']['coordinates'][0]

concelhos_plot = {}
for key, value in concelhos_dict.items():
    concelhos_plot[key] = [[point[0] for point in value], [point[1] for point in value] ]

# %%
plt.figure(figsize=(5,10))
plt.xlim((-9.6, -6))
plt.ylim((36.7, 42.2))
for name, fr in concelhos_plot.items():
    if name in seniors_df.County_of_Origin.unique():
        c = 'red'
    else:
        c = 'blue'
    plt.plot(fr[0], fr[1], color=c , linewidth=1)
plt.show()

# %%
seniors_df.groupby('County_of_Origin')['Average_Daily_SeniorPopulation_Travelling'].mean().sort_values(ascending=False)
# Out:
# County_of_Origin
# Maia                    2592.685676
# Porto                   1853.670545
# Palmela                 1682.594495
# Gondomar                1007.366209
# Lisboa                   828.232138
# Matosinhos               811.815903
# Odivelas                 754.966313
# Montijo                  741.242802
# Cascais                  545.218368
# Barreiro                 515.790044
# Setúbal                  472.899427
# Vila Franca de Xira      460.025017
# Sintra                   457.432288
# Alcochete                449.138928
# Oeiras                   441.723595
# Sesimbra                 440.766744
# Seixal                   403.714357
# Santa Maria da Feira     331.354878
# Moita                    310.777968
# Mafra                    233.917902
# Loures                   228.332742
# Amadora                  209.128946
# Almada                    64.208721
# Name: Average_Daily_SeniorPopulation_Travelling, dtype: float64

# %%
seniors_df.groupby('County_of_Origin')['IDRoute'].nunique().sort_values(ascending=False)
# Out:
# County_of_Origin
# Oeiras                  152
# Lisboa                  132
# Odivelas                120
# Barreiro                119
# Porto                   110
# Seixal                  110
# Sintra                  107
# Vila Franca de Xira     100
# Maia                     99
# Cascais                  98
# Gondomar                 95
# Amadora                  92
# Mafra                    81
# Palmela                  68
# Loures                   51
# Almada                   44
# Matosinhos               33
# Setúbal                  29
# Sesimbra                 24
# Santa Maria da Feira     16
# Montijo                  15
# Alcochete                 8
# Moita                     0
# Name: IDRoute, dtype: int64

# %%
route_counties={}
for route in seniors_df.IDRoute.unique():
    temp = seniors_df.dropna()
    route_counties[route] = list(temp[(temp.IDRoute==route)].County_of_Origin.unique())
    print(len(route_counties[route]), end= ' ')
# Out:
# 17 10 14 13 14 16 16 14 0 16 14 13 19 13 15 15 15 15 16 18 15 18 17 17 15 16 9 10 14 17 11 20 15 15 15 16 10 9 11 11 14 15 16 11 15 14 9 12 9 15 14 14 15 11 15 15 11 16 12 12 12 14 15 7 11 11 12 10 15 13 13 8 11 11 11 11 11 15 11 14 10 8 14 9 7 1 11 13 2 7 4 9 3 9 10 9 9 3 5 9 7 10 8 10 9 10 9 10 10 7 9 9 10 10 8 10 8 10 6 12 11 9 9 10 11 6 4 4 5 8 9 8 6 7 8 9 8 8 6 9 5 5 8 8 4 4 8 5 6 9 6 7 7 7 6 8 7 5 4 1 7 3 9 9 1 0 0

# %%
route_counties
# Out:
# {8.0: ['Lisboa',
#   'Palmela',
#   'Oeiras',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Loures',
#   'Amadora',
#   'Barreiro',
#   'Odivelas',
#   'Seixal',
#   'Montijo',
#   'Porto',
#   'Mafra',
#   'Santa Maria da Feira',
#   'Cascais',
#   'Almada',
#   'Maia'],
#  85.0: ['Lisboa',
#   'Palmela',
#   'Oeiras',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Maia',
#   'Barreiro',
#   'Seixal',
#   'Cascais',
#   'Odivelas'],
#  6.0: ['Lisboa',
#   'Seixal',
#   'Odivelas',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Palmela',
#   'Mafra',
#   'Setúbal',
#   'Barreiro',
#   'Amadora',
#   'Cascais',
#   'Loures',
#   'Porto'],
#  33.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Cascais',
#   'Amadora',
#   'Barreiro',
#   'Odivelas',
#   'Mafra',
#   'Oeiras',
#   'Sintra',
#   'Seixal',
#   'Sesimbra',
#   'Palmela',
#   'Loures'],
#  52.0: ['Lisboa',
#   'Seixal',
#   'Odivelas',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Palmela',
#   'Barreiro',
#   'Mafra',
#   'Porto',
#   'Cascais',
#   'Amadora',
#   'Loures',
#   'Gondomar'],
#  9.0: ['Oeiras',
#   'Barreiro',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Palmela',
#   'Sintra',
#   'Cascais',
#   'Santa Maria da Feira',
#   'Mafra',
#   'Amadora',
#   'Montijo',
#   'Loures',
#   'Porto',
#   'Alcochete',
#   'Seixal'],
#  46.0: ['Oeiras',
#   'Mafra',
#   'Vila Franca de Xira',
#   'Montijo',
#   'Cascais',
#   'Amadora',
#   'Palmela',
#   'Lisboa',
#   'Barreiro',
#   'Odivelas',
#   'Sintra',
#   'Santa Maria da Feira',
#   'Porto',
#   'Loures',
#   'Sesimbra',
#   'Alcochete'],
#  82.0: ['Oeiras',
#   'Barreiro',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Mafra',
#   'Sintra',
#   'Odivelas',
#   'Santa Maria da Feira',
#   'Cascais',
#   'Amadora',
#   'Porto',
#   'Palmela',
#   'Loures',
#   'Seixal'],
#  nan: [],
#  5.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Almada',
#   'Amadora',
#   'Seixal',
#   'Barreiro',
#   'Odivelas',
#   'Loures',
#   'Maia',
#   'Sintra',
#   'Palmela',
#   'Setúbal',
#   'Cascais',
#   'Mafra',
#   'Porto'],
#  36.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Almada',
#   'Amadora',
#   'Seixal',
#   'Maia',
#   'Sintra',
#   'Barreiro',
#   'Palmela',
#   'Odivelas',
#   'Cascais',
#   'Mafra',
#   'Setúbal'],
#  59.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Almada',
#   'Amadora',
#   'Seixal',
#   'Sintra',
#   'Maia',
#   'Barreiro',
#   'Palmela',
#   'Odivelas',
#   'Cascais',
#   'Mafra'],
#  63.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Almada',
#   'Amadora',
#   'Seixal',
#   'Sintra',
#   'Barreiro',
#   'Odivelas',
#   'Palmela',
#   'Porto',
#   'Maia',
#   'Setúbal',
#   'Cascais',
#   'Sesimbra',
#   'Montijo',
#   'Santa Maria da Feira',
#   'Mafra',
#   'Alcochete'],
#  69.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Almada',
#   'Amadora',
#   'Seixal',
#   'Maia',
#   'Sintra',
#   'Barreiro',
#   'Palmela',
#   'Cascais',
#   'Odivelas',
#   'Porto'],
#  72.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Almada',
#   'Amadora',
#   'Seixal',
#   'Maia',
#   'Sintra',
#   'Mafra',
#   'Porto',
#   'Barreiro',
#   'Odivelas',
#   'Loures',
#   'Cascais',
#   'Setúbal'],
#  4.0: ['Oeiras',
#   'Sintra',
#   'Barreiro',
#   'Lisboa',
#   'Odivelas',
#   'Seixal',
#   'Vila Franca de Xira',
#   'Loures',
#   'Cascais',
#   'Almada',
#   'Porto',
#   'Setúbal',
#   'Sesimbra',
#   'Palmela',
#   'Amadora'],
#  64.0: ['Oeiras',
#   'Sintra',
#   'Barreiro',
#   'Lisboa',
#   'Seixal',
#   'Odivelas',
#   'Loures',
#   'Vila Franca de Xira',
#   'Amadora',
#   'Cascais',
#   'Almada',
#   'Porto',
#   'Setúbal',
#   'Sesimbra',
#   'Palmela'],
#  12.0: ['Oeiras',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Palmela',
#   'Barreiro',
#   'Odivelas',
#   'Sintra',
#   'Cascais',
#   'Mafra',
#   'Amadora',
#   'Montijo',
#   'Santa Maria da Feira',
#   'Porto',
#   'Loures',
#   'Alcochete'],
#  28.0: ['Oeiras',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Loures',
#   'Amadora',
#   'Odivelas',
#   'Seixal',
#   'Montijo',
#   'Porto',
#   'Barreiro',
#   'Mafra',
#   'Cascais',
#   'Palmela',
#   'Almada',
#   'Santa Maria da Feira'],
#  30.0: ['Oeiras',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Palmela',
#   'Sintra',
#   'Mafra',
#   'Loures',
#   'Amadora',
#   'Odivelas',
#   'Seixal',
#   'Montijo',
#   'Porto',
#   'Barreiro',
#   'Santa Maria da Feira',
#   'Cascais',
#   'Gondomar',
#   'Almada',
#   'Alcochete'],
#  43.0: ['Oeiras',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Loures',
#   'Amadora',
#   'Odivelas',
#   'Seixal',
#   'Montijo',
#   'Porto',
#   'Barreiro',
#   'Mafra',
#   'Palmela',
#   'Almada',
#   'Cascais'],
#  58.0: ['Oeiras',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Loures',
#   'Amadora',
#   'Odivelas',
#   'Seixal',
#   'Montijo',
#   'Porto',
#   'Barreiro',
#   'Mafra',
#   'Cascais',
#   'Santa Maria da Feira',
#   'Palmela',
#   'Almada',
#   'Gondomar',
#   'Alcochete'],
#  70.0: ['Oeiras',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Loures',
#   'Amadora',
#   'Odivelas',
#   'Seixal',
#   'Montijo',
#   'Porto',
#   'Barreiro',
#   'Maia',
#   'Palmela',
#   'Mafra',
#   'Santa Maria da Feira',
#   'Cascais',
#   'Almada'],
#  83.0: ['Oeiras',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Odivelas',
#   'Sintra',
#   'Loures',
#   'Amadora',
#   'Seixal',
#   'Montijo',
#   'Porto',
#   'Mafra',
#   'Cascais',
#   'Palmela',
#   'Santa Maria da Feira',
#   'Almada',
#   'Alcochete'],
#  44.0: ['Sintra',
#   'Lisboa',
#   'Barreiro',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Amadora',
#   'Oeiras',
#   'Loures',
#   'Seixal',
#   'Cascais',
#   'Mafra',
#   'Setúbal',
#   'Almada',
#   'Palmela',
#   'Sesimbra'],
#  86.0: ['Sintra',
#   'Lisboa',
#   'Barreiro',
#   'Palmela',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Odivelas',
#   'Cascais',
#   'Seixal',
#   'Amadora',
#   'Montijo',
#   'Mafra',
#   'Santa Maria da Feira',
#   'Maia',
#   'Porto',
#   'Alcochete'],
#  16.0: ['Lisboa',
#   'Palmela',
#   'Maia',
#   'Barreiro',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Sintra',
#   'Oeiras',
#   'Amadora'],
#  15.0: ['Maia',
#   'Palmela',
#   'Odivelas',
#   'Lisboa',
#   'Cascais',
#   'Barreiro',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Sintra',
#   'Amadora'],
#  62.0: ['Maia',
#   'Palmela',
#   'Odivelas',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Seixal',
#   'Barreiro',
#   'Mafra',
#   'Cascais',
#   'Sintra',
#   'Amadora',
#   'Almada',
#   'Gondomar'],
#  67.0: ['Maia',
#   'Palmela',
#   'Odivelas',
#   'Lisboa',
#   'Oeiras',
#   'Barreiro',
#   'Seixal',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Amadora',
#   'Mafra',
#   'Porto',
#   'Cascais',
#   'Loures',
#   'Almada',
#   'Setúbal',
#   'Gondomar'],
#  14.0: ['Odivelas',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Mafra',
#   'Oeiras',
#   'Sintra',
#   'Barreiro',
#   'Amadora',
#   'Santa Maria da Feira',
#   'Porto',
#   'Palmela'],
#  49.0: ['Odivelas',
#   'Lisboa',
#   'Seixal',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Palmela',
#   'Amadora',
#   'Cascais',
#   'Santa Maria da Feira',
#   'Porto',
#   'Barreiro',
#   'Mafra',
#   'Loures',
#   'Setúbal',
#   'Maia',
#   'Almada',
#   'Sesimbra',
#   'Gondomar',
#   'Montijo'],
#  84.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Seixal',
#   'Odivelas',
#   'Sintra',
#   'Oeiras',
#   'Palmela',
#   'Amadora',
#   'Mafra',
#   'Santa Maria da Feira',
#   'Cascais',
#   'Loures',
#   'Porto',
#   'Gondomar'],
#  37.0: ['Seixal',
#   'Odivelas',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Lisboa',
#   'Palmela',
#   'Cascais',
#   'Montijo',
#   'Barreiro',
#   'Mafra',
#   'Porto',
#   'Setúbal',
#   'Amadora',
#   'Loures'],
#  53.0: ['Seixal',
#   'Odivelas',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Lisboa',
#   'Palmela',
#   'Mafra',
#   'Setúbal',
#   'Loures',
#   'Barreiro',
#   'Amadora',
#   'Cascais',
#   'Gondomar',
#   'Porto'],
#  74.0: ['Seixal',
#   'Odivelas',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Lisboa',
#   'Palmela',
#   'Amadora',
#   'Mafra',
#   'Barreiro',
#   'Loures',
#   'Maia',
#   'Almada',
#   'Gondomar',
#   'Porto',
#   'Cascais'],
#  19.0: ['Vila Franca de Xira',
#   'Sintra',
#   'Lisboa',
#   'Odivelas',
#   'Loures',
#   'Palmela',
#   'Oeiras',
#   'Amadora',
#   'Mafra',
#   'Gondomar'],
#  20.0: ['Vila Franca de Xira',
#   'Sintra',
#   'Lisboa',
#   'Odivelas',
#   'Mafra',
#   'Palmela',
#   'Oeiras',
#   'Amadora',
#   'Gondomar'],
#  60.0: ['Vila Franca de Xira',
#   'Sintra',
#   'Lisboa',
#   'Barreiro',
#   'Odivelas',
#   'Oeiras',
#   'Amadora',
#   'Mafra',
#   'Loures',
#   'Gondomar',
#   'Seixal'],
#  81.0: ['Vila Franca de Xira',
#   'Sintra',
#   'Lisboa',
#   'Odivelas',
#   'Barreiro',
#   'Oeiras',
#   'Mafra',
#   'Seixal',
#   'Maia',
#   'Amadora',
#   'Gondomar'],
#  40.0: ['Vila Franca de Xira',
#   'Lisboa',
#   'Oeiras',
#   'Palmela',
#   'Sintra',
#   'Odivelas',
#   'Santa Maria da Feira',
#   'Amadora',
#   'Cascais',
#   'Loures',
#   'Barreiro',
#   'Seixal',
#   'Porto',
#   'Mafra'],
#  7.0: ['Vila Franca de Xira',
#   'Seixal',
#   'Lisboa',
#   'Odivelas',
#   'Cascais',
#   'Montijo',
#   'Palmela',
#   'Oeiras',
#   'Sintra',
#   'Barreiro',
#   'Amadora',
#   'Mafra',
#   'Setúbal',
#   'Loures',
#   'Gondomar'],
#  66.0: ['Vila Franca de Xira',
#   'Maia',
#   'Lisboa',
#   'Oeiras',
#   'Sintra',
#   'Mafra',
#   'Porto',
#   'Seixal',
#   'Almada',
#   'Odivelas',
#   'Barreiro',
#   'Amadora',
#   'Palmela',
#   'Cascais',
#   'Loures',
#   'Gondomar'],
#  90.0: ['Vila Franca de Xira',
#   'Maia',
#   'Lisboa',
#   'Oeiras',
#   'Sintra',
#   'Mafra',
#   'Seixal',
#   'Odivelas',
#   'Amadora',
#   'Almada',
#   'Barreiro'],
#  32.0: ['Lisboa',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Amadora',
#   'Porto',
#   'Oeiras',
#   'Maia',
#   'Odivelas',
#   'Seixal',
#   'Barreiro',
#   'Almada',
#   'Cascais',
#   'Mafra',
#   'Setúbal',
#   'Palmela'],
#  77.0: ['Seixal',
#   'Sintra',
#   'Almada',
#   'Lisboa',
#   'Barreiro',
#   'Oeiras',
#   'Palmela',
#   'Amadora',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Maia',
#   'Setúbal',
#   'Cascais',
#   'Porto'],
#  87.0: ['Seixal',
#   'Odivelas',
#   'Lisboa',
#   'Mafra',
#   'Vila Franca de Xira',
#   'Palmela',
#   'Sintra',
#   'Loures',
#   'Amadora'],
#  89.0: ['Seixal',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Cascais',
#   'Mafra',
#   'Odivelas',
#   'Sintra',
#   'Setúbal',
#   'Amadora',
#   'Gondomar'],
#  18.0: ['Vila Franca de Xira',
#   'Oeiras',
#   'Setúbal',
#   'Odivelas',
#   'Lisboa',
#   'Mafra',
#   'Palmela',
#   'Loures',
#   'Seixal'],
#  27.0: ['Vila Franca de Xira',
#   'Setúbal',
#   'Odivelas',
#   'Lisboa',
#   'Loures',
#   'Mafra',
#   'Palmela',
#   'Sintra',
#   'Barreiro',
#   'Amadora',
#   'Oeiras',
#   'Maia',
#   'Almada',
#   'Seixal',
#   'Cascais'],
#  75.0: ['Barreiro',
#   'Seixal',
#   'Vila Franca de Xira',
#   'Loures',
#   'Lisboa',
#   'Odivelas',
#   'Sintra',
#   'Amadora',
#   'Oeiras',
#   'Cascais',
#   'Mafra',
#   'Almada',
#   'Palmela',
#   'Setúbal'],
#  47.0: ['Lisboa',
#   'Barreiro',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Oeiras',
#   'Sintra',
#   'Seixal',
#   'Maia',
#   'Amadora',
#   'Almada',
#   'Loures',
#   'Mafra',
#   'Cascais',
#   'Sesimbra'],
#  42.0: ['Lisboa',
#   'Oeiras',
#   'Amadora',
#   'Seixal',
#   'Mafra',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Barreiro',
#   'Odivelas',
#   'Almada',
#   'Loures',
#   'Setúbal',
#   'Cascais',
#   'Palmela',
#   'Maia'],
#  73.0: ['Lisboa',
#   'Seixal',
#   'Oeiras',
#   'Loures',
#   'Amadora',
#   'Vila Franca de Xira',
#   'Mafra',
#   'Sintra',
#   'Maia',
#   'Odivelas',
#   'Cascais'],
#  25.0: ['Seixal',
#   'Lisboa',
#   'Oeiras',
#   'Vila Franca de Xira',
#   'Amadora',
#   'Loures',
#   'Odivelas',
#   'Setúbal',
#   'Cascais',
#   'Sintra',
#   'Almada',
#   'Barreiro',
#   'Palmela',
#   'Mafra',
#   'Porto'],
#  55.0: ['Amadora',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Barreiro',
#   'Sintra',
#   'Mafra',
#   'Oeiras',
#   'Porto',
#   'Cascais',
#   'Loures',
#   'Seixal',
#   'Palmela',
#   'Almada',
#   'Gondomar'],
#  38.0: ['Lisboa',
#   'Cascais',
#   'Palmela',
#   'Odivelas',
#   'Barreiro',
#   'Vila Franca de Xira',
#   'Maia',
#   'Oeiras',
#   'Amadora',
#   'Sintra',
#   'Seixal'],
#  45.0: ['Oeiras',
#   'Seixal',
#   'Lisboa',
#   'Sintra',
#   'Odivelas',
#   'Amadora',
#   'Mafra',
#   'Sesimbra',
#   'Cascais',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Loures',
#   'Almada',
#   'Palmela',
#   'Gondomar',
#   'Porto'],
#  68.0: ['Vila Franca de Xira',
#   'Oeiras',
#   'Barreiro',
#   'Lisboa',
#   'Odivelas',
#   'Seixal',
#   'Sintra',
#   'Mafra',
#   'Amadora',
#   'Palmela',
#   'Gondomar',
#   'Almada'],
#  39.0: ['Lisboa',
#   'Oeiras',
#   'Barreiro',
#   'Amadora',
#   'Seixal',
#   'Sintra',
#   'Odivelas',
#   'Vila Franca de Xira',
#   'Cascais',
#   'Mafra',
#   'Palmela',
#   'Almada'],
#  48.0: ['Lisboa',
#   'Oeiras',
#   'Palmela',
#   'Odivelas',
#   'Amadora',
#   'Seixal',
#   'Vila Franca de Xira',
#   'Cascais',
#   'Sintra',
#   'Sesimbra',
#   'Barreiro',
#   'Mafra'],
#  34.0: ['Lisboa',
#   'Barreiro',
#   'Oeiras',
#   'Amadora',
#   'Seixal',
#   'Sintra',
#   'Almada',
#   'Vila Franca de Xira',
#   'Cascais',
#   'Odivelas',
#   'Porto',
#   'Mafra',
#   'Palmela',
#   'Sesimbra'],
#  57.0: ['Lisboa',
#   'Sintra',
#   'Seixal',
#   'Oeiras',
#   'Almada',
#   'Vila Franca de Xira',
#   'Cascais',
#   'Barreiro',
#   'Odivelas',
#   'Gondomar',
#   'Amadora',
#   'Palmela',
#   'Porto',
#   'Mafra',
#   'Sesimbra'],
#  88.0: ['Odivelas',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Seixal',
#   'Oeiras',
#   'Mafra',
#   'Barreiro'],
#  17.0: ['Oeiras',
#   'Lisboa',
#   'Odivelas',
#   'Seixal',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Palmela',
#   'Amadora',
#   'Mafra',
#   'Cascais',
#   'Barreiro'],
#  26.0: ['Palmela',
#   'Lisboa',
#   'Oeiras',
#   'Seixal',
#   'Sintra',
#   'Almada',
#   'Amadora',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Cascais',
#   'Setúbal'],
#  29.0: ['Lisboa',
#   'Seixal',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Oeiras',
#   'Barreiro',
#   'Loures',
#   'Amadora',
#   'Cascais',
#   'Sesimbra',
#   'Mafra'],
#  65.0: ['Cascais',
#   'Amadora',
#   'Oeiras',
#   'Lisboa',
#   'Sintra',
#   'Palmela',
#   'Seixal',
#   'Vila Franca de Xira',
#   'Odivelas',
#   'Barreiro'],
#  71.0: ['Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Odivelas',
#   'Mafra',
#   'Seixal',
#   'Sintra',
#   'Amadora',
#   'Vila Franca de Xira',
#   'Cascais',
#   'Almada',
#   'Palmela',
#   'Loures',
#   'Sesimbra',
#   'Gondomar'],
#  79.0: ['Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Sintra',
#   'Loures',
#   'Odivelas',
#   'Mafra',
#   'Amadora',
#   'Cascais',
#   'Seixal',
#   'Vila Franca de Xira',
#   'Sesimbra',
#   'Palmela'],
#  41.0: ['Cascais',
#   'Oeiras',
#   'Lisboa',
#   'Amadora',
#   'Odivelas',
#   'Seixal',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Almada',
#   'Sesimbra',
#   'Palmela',
#   'Mafra'],
#  10.0: ['Oeiras',
#   'Lisboa',
#   'Seixal',
#   'Barreiro',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Amadora',
#   'Cascais'],
#  61.0: ['Lisboa',
#   'Seixal',
#   'Oeiras',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Amadora',
#   'Barreiro',
#   'Setúbal',
#   'Porto',
#   'Almada',
#   'Odivelas'],
#  13.0: ['Vila Franca de Xira',
#   'Barreiro',
#   'Odivelas',
#   'Oeiras',
#   'Lisboa',
#   'Seixal',
#   'Amadora',
#   'Cascais',
#   'Mafra',
#   'Sintra',
#   'Sesimbra'],
#  51.0: ['Vila Franca de Xira',
#   'Barreiro',
#   'Odivelas',
#   'Oeiras',
#   'Lisboa',
#   'Seixal',
#   'Amadora',
#   'Cascais',
#   'Mafra',
#   'Sintra',
#   'Sesimbra'],
#  31.0: ['Lisboa',
#   'Loures',
#   'Oeiras',
#   'Odivelas',
#   'Barreiro',
#   'Seixal',
#   'Amadora',
#   'Sintra',
#   'Cascais',
#   'Palmela',
#   'Vila Franca de Xira'],
#  78.0: ['Oeiras',
#   'Lisboa',
#   'Cascais',
#   'Vila Franca de Xira',
#   'Amadora',
#   'Barreiro',
#   'Palmela',
#   'Seixal',
#   'Odivelas',
#   'Loures',
#   'Sintra'],
#  35.0: ['Oeiras',
#   'Barreiro',
#   'Sesimbra',
#   'Sintra',
#   'Odivelas',
#   'Lisboa',
#   'Seixal',
#   'Mafra',
#   'Vila Franca de Xira',
#   'Loures',
#   'Cascais',
#   'Amadora',
#   'Almada',
#   'Setúbal',
#   'Palmela'],
#  91.0: ['Oeiras',
#   'Barreiro',
#   'Sesimbra',
#   'Sintra',
#   'Mafra',
#   'Loures',
#   'Vila Franca de Xira',
#   'Lisboa',
#   'Amadora',
#   'Odivelas',
#   'Cascais'],
#  50.0: ['Sesimbra',
#   'Oeiras',
#   'Sintra',
#   'Odivelas',
#   'Barreiro',
#   'Lisboa',
#   'Seixal',
#   'Loures',
#   'Mafra',
#   'Amadora',
#   'Cascais',
#   'Vila Franca de Xira',
#   'Almada',
#   'Palmela'],
#  11.0: ['Lisboa',
#   'Oeiras',
#   'Barreiro',
#   'Seixal',
#   'Amadora',
#   'Odivelas',
#   'Sintra',
#   'Mafra',
#   'Cascais',
#   'Vila Franca de Xira'],
#  1.0: ['Odivelas',
#   'Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Seixal',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Amadora'],
#  2.0: ['Lisboa',
#   'Barreiro',
#   'Odivelas',
#   'Oeiras',
#   'Seixal',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Loures',
#   'Cascais',
#   'Amadora',
#   'Almada',
#   'Sesimbra',
#   'Porto',
#   'Palmela'],
#  76.0: ['Setúbal',
#   'Oeiras',
#   'Seixal',
#   'Lisboa',
#   'Amadora',
#   'Vila Franca de Xira',
#   'Mafra',
#   'Odivelas',
#   'Loures'],
#  54.0: ['Sintra',
#   'Odivelas',
#   'Barreiro',
#   'Oeiras',
#   'Lisboa',
#   'Seixal',
#   'Amadora'],
#  23.0: ['Lisboa'],
#  56.0: ['Seixal',
#   'Lisboa',
#   'Oeiras',
#   'Sintra',
#   'Odivelas',
#   'Sesimbra',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Cascais',
#   'Palmela',
#   'Almada'],
#  3.0: ['Amadora',
#   'Seixal',
#   'Odivelas',
#   'Oeiras',
#   'Barreiro',
#   'Lisboa',
#   'Vila Franca de Xira',
#   'Sintra',
#   'Loures',
#   'Cascais',
#   'Almada',
#   'Palmela',
#   'Sesimbra'],
#  21.0: ['Barreiro', 'Lisboa'],
#  80.0: ['Barreiro',
#   'Oeiras',
#   'Setúbal',
#   'Sintra',
#   'Lisboa',
#   'Porto',
#   'Amadora'],
#  104.0: ['Maia', 'Gondomar', 'Matosinhos', 'Porto'],
#  146.0: ['Gondomar',
#   'Maia',
#   'Odivelas',
#   'Porto',
#   'Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Sintra',
#   'Cascais'],
#  162.0: ['Gondomar', 'Maia', 'Oeiras'],
#  115.0: ['Porto',
#   'Sintra',
#   'Maia',
#   'Gondomar',
#   'Cascais',
#   'Lisboa',
#   'Oeiras',
#   'Barreiro',
#   'Vila Franca de Xira'],
#  118.0: ['Porto',
#   'Sintra',
#   'Maia',
#   'Gondomar',
#   'Odivelas',
#   'Lisboa',
#   'Oeiras',
#   'Barreiro',
#   'Vila Franca de Xira',
#   'Cascais'],
#  152.0: ['Porto',
#   'Sintra',
#   'Maia',
#   'Gondomar',
#   'Cascais',
#   'Lisboa',
#   'Oeiras',
#   'Barreiro',
#   'Vila Franca de Xira'],
#  147.0: ['Gondomar',
#   'Maia',
#   'Odivelas',
#   'Porto',
#   'Oeiras',
#   'Lisboa',
#   'Cascais',
#   'Barreiro',
#   'Sintra'],
#  149.0: ['Gondomar', 'Maia', 'Oeiras'],
#  151.0: ['Gondomar', 'Maia', 'Odivelas', 'Porto', 'Oeiras'],
#  142.0: ['Lisboa',
#   'Maia',
#   'Gondomar',
#   'Porto',
#   'Matosinhos',
#   'Sintra',
#   'Cascais',
#   'Odivelas',
#   'Oeiras'],
#  141.0: ['Gondomar',
#   'Cascais',
#   'Maia',
#   'Porto',
#   'Oeiras',
#   'Matosinhos',
#   'Odivelas'],
#  94.0: ['Vila Franca de Xira',
#   'Maia',
#   'Porto',
#   'Barreiro',
#   'Sintra',
#   'Gondomar',
#   'Matosinhos',
#   'Lisboa',
#   'Oeiras',
#   'Cascais'],
#  157.0: ['Vila Franca de Xira',
#   'Maia',
#   'Porto',
#   'Barreiro',
#   'Gondomar',
#   'Lisboa',
#   'Cascais',
#   'Oeiras'],
#  93.0: ['Vila Franca de Xira',
#   'Odivelas',
#   'Barreiro',
#   'Porto',
#   'Cascais',
#   'Lisboa',
#   'Mafra',
#   'Gondomar',
#   'Maia',
#   'Oeiras'],
#  153.0: ['Vila Franca de Xira',
#   'Maia',
#   'Oeiras',
#   'Porto',
#   'Gondomar',
#   'Lisboa',
#   'Cascais',
#   'Mafra',
#   'Barreiro'],
#  158.0: ['Vila Franca de Xira',
#   'Odivelas',
#   'Maia',
#   'Gondomar',
#   'Lisboa',
#   'Cascais',
#   'Porto',
#   'Oeiras',
#   'Mafra',
#   'Barreiro'],
#  95.0: ['Mafra',
#   'Maia',
#   'Porto',
#   'Seixal',
#   'Gondomar',
#   'Oeiras',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Lisboa'],
#  156.0: ['Mafra',
#   'Maia',
#   'Porto',
#   'Seixal',
#   'Gondomar',
#   'Oeiras',
#   'Vila Franca de Xira',
#   'Barreiro',
#   'Lisboa',
#   'Matosinhos'],
#  160.0: ['Mafra',
#   'Maia',
#   'Odivelas',
#   'Porto',
#   'Vila Franca de Xira',
#   'Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Gondomar',
#   'Seixal'],
#  136.0: ['Porto', 'Gondomar', 'Maia', 'Amadora', 'Oeiras', 'Cascais', 'Mafra'],
#  137.0: ['Porto',
#   'Gondomar',
#   'Maia',
#   'Odivelas',
#   'Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Sintra',
#   'Cascais'],
#  161.0: ['Porto',
#   'Gondomar',
#   'Maia',
#   'Odivelas',
#   'Oeiras',
#   'Lisboa',
#   'Barreiro',
#   'Sintra',
#   'Cascais'],
#  145.0: ['Gondomar',
#   'Maia',
#   'Porto',
#   'Matosinhos',
#   'Odivelas',
#   'Oeiras',
#   'Lisboa',
#   'Cascais',
#   'Barreiro',
#   'Sintra'],
#  135.0: ['Maia',
#   'Sintra',
#   'Porto',
#   'Gondomar',
#   'Lisboa',
#   'Odivelas',
#   'Seixal',
#   'Matosinhos',
#   'Barreiro',
#   'Oeiras'],
#  120.0: ['Porto',
#   'Maia',
#   'Oeiras',
#   'Gondomar',
#   'Seixal',
#   'Lisboa',
#   'Odivelas',
#   'Barreiro'],
#  126.0: ['Porto',
#   'Maia',
#   'Sintra',
#   'Gondomar',
#   'Oeiras',
#   'Seixal',
#   'Amadora',
#   'Matosinhos',
#   'Barreiro',
#   'Mafra'],
#  131.0: ['Porto',
#   'Maia',
#   'Oeiras',
#   'Gondomar',
#   'Seixal',
#   'Lisboa',
#   'Odivelas',
#   'Barreiro'],
#  105.0: ['Porto',
#   'Oeiras',
#   'Maia',
#   'Gondomar',
#   'Sintra',
#   'Lisboa',
#   'Odivelas',
#   'Barreiro',
#   'Vila Franca de Xira',
#   'Seixal'],
#  124.0: ['Porto', 'Oeiras', 'Lisboa', 'Maia', 'Matosinhos', 'Gondomar'],
#  103.0: ['Sintra',
#   'Porto',
#   'Maia',
#   'Gondomar',
#   'Barreiro',
#   'Matosinhos',
#   'Seixal',
#   'Oeiras',
#   'Odivelas',
#   'Lisboa',
#   'Mafra',
#   'Cascais'],
#  111.0: ['Sintra',
#   'Maia',
#   'Porto',
#   'Gondomar',
#   'Barreiro',
#   'Oeiras',
#   'Odivelas',
#   'Lisboa',
#   'Cascais',
#   'Vila Franca de Xira',
#   'Matosinhos'],
#  127.0: ['Sintra',
#   'Maia',
#   'Gondomar',
#   'Porto',
#   'Matosinhos',
#   'Oeiras',
#   'Amadora',
#   'Odivelas',
#   'Mafra'],
#  134.0: ['Sintra',
#   'Maia',
#   'Porto',
#   'Gondomar',
#   'Barreiro',
#   'Lisboa',
#   'Odivelas',
#   'Matosinhos',
#   'Oeiras'],
#  148.0: ['Porto',
#   'Maia',
#   'Gondomar',
#   'Lisboa',
#   'Matosinhos',
#   'Odivelas',
#   'Cascais',
#   'Sintra',
#   'Barreiro',
#   'Oeiras'],
#  110.0: ['Maia',
#   'Porto',
#   'Gondomar',
#   'Oeiras',
#   'Odivelas',
#   'Barreiro',
#   'Cascais',
#   'Lisboa',
#   'Sintra',
#   'Vila Franca de Xira',
#   'Matosinhos'],
#  130.0: ['Gondomar', 'Maia', 'Porto', 'Oeiras', 'Lisboa', 'Cascais'],
#  138.0: ['Gondomar', 'Maia', 'Porto', 'Oeiras'],
#  139.0: ['Gondomar', 'Maia', 'Porto', 'Oeiras'],
#  140.0: ['Gondomar', 'Maia', 'Porto', 'Oeiras', 'Cascais'],
#  116.0: ['Setúbal',
#   'Porto',
#   'Maia',
#   'Gondomar',
#   'Oeiras',
#   'Odivelas',
#   'Barreiro',
#   'Seixal'],
#  129.0: ['Setúbal',
#   'Porto',
#   'Maia',
#   'Gondomar',
#   'Oeiras',
#   'Odivelas',
#   'Barreiro',
#   'Seixal',
#   'Matosinhos'],
#  133.0: ['Setúbal',
#   'Porto',
#   'Maia',
#   'Gondomar',
#   'Oeiras',
#   'Odivelas',
#   'Barreiro',
#   'Cascais'],
#  114.0: ['Porto', 'Maia', 'Gondomar', 'Oeiras', 'Odivelas', 'Lisboa'],
#  100.0: ['Lisboa',
#   'Maia',
#   'Matosinhos',
#   'Porto',
#   'Gondomar',
#   'Oeiras',
#   'Seixal'],
#  125.0: ['Maia',
#   'Gondomar',
#   'Lisboa',
#   'Matosinhos',
#   'Amadora',
#   'Porto',
#   'Seixal',
#   'Mafra'],
#  96.0: ['Matosinhos',
#   'Maia',
#   'Gondomar',
#   'Porto',
#   'Lisboa',
#   'Oeiras',
#   'Amadora',
#   'Odivelas',
#   'Seixal'],
#  122.0: ['Maia',
#   'Matosinhos',
#   'Gondomar',
#   'Porto',
#   'Oeiras',
#   'Odivelas',
#   'Lisboa',
#   'Seixal'],
#  107.0: ['Maia',
#   'Lisboa',
#   'Gondomar',
#   'Matosinhos',
#   'Porto',
#   'Oeiras',
#   'Odivelas',
#   'Seixal'],
#  119.0: ['Gondomar', 'Maia', 'Odivelas', 'Porto', 'Seixal', 'Oeiras'],
#  108.0: ['Maia',
#   'Gondomar',
#   'Matosinhos',
#   'Porto',
#   'Amadora',
#   'Seixal',
#   'Oeiras',
#   'Mafra',
#   'Lisboa'],
#  101.0: ['Gondomar', 'Maia', 'Porto', 'Matosinhos', 'Odivelas'],
#  117.0: ['Gondomar', 'Maia', 'Porto', 'Barreiro', 'Seixal'],
#  113.0: ['Odivelas',
#   'Maia',
#   'Porto',
#   'Gondomar',
#   'Lisboa',
#   'Oeiras',
#   'Sintra',
#   'Seixal'],
#  112.0: ['Odivelas',
#   'Porto',
#   'Maia',
#   'Gondomar',
#   'Lisboa',
#   'Oeiras',
#   'Sintra',
#   'Seixal'],
#  163.0: ['Odivelas', 'Gondomar', 'Maia', 'Porto'],
#  102.0: ['Gondomar', 'Matosinhos', 'Maia', 'Porto'],
#  106.0: ['Gondomar',
#   'Matosinhos',
#   'Porto',
#   'Seixal',
#   'Maia',
#   'Oeiras',
#   'Mafra',
#   'Barreiro'],
#  123.0: ['Maia', 'Porto', 'Gondomar', 'Amadora', 'Oeiras'],
#  98.0: ['Gondomar', 'Matosinhos', 'Porto', 'Seixal', 'Maia', 'Oeiras'],
#  99.0: ['Gondomar',
#   'Matosinhos',
#   'Porto',
#   'Seixal',
#   'Maia',
#   'Oeiras',
#   'Lisboa',
#   'Cascais',
#   'Mafra'],
#  121.0: ['Porto', 'Matosinhos', 'Maia', 'Gondomar', 'Amadora', 'Oeiras'],
#  155.0: ['Maia',
#   'Porto',
#   'Seixal',
#   'Gondomar',
#   'Oeiras',
#   'Vila Franca de Xira',
#   'Matosinhos'],
#  128.0: ['Porto',
#   'Maia',
#   'Gondomar',
#   'Oeiras',
#   'Matosinhos',
#   'Amadora',
#   'Seixal'],
#  132.0: ['Porto',
#   'Maia',
#   'Gondomar',
#   'Oeiras',
#   'Odivelas',
#   'Matosinhos',
#   'Seixal'],
#  165.0: ['Porto', 'Seixal', 'Maia', 'Gondomar', 'Cascais', 'Oeiras'],
#  154.0: ['Maia',
#   'Oeiras',
#   'Porto',
#   'Gondomar',
#   'Lisboa',
#   'Cascais',
#   'Barreiro',
#   'Odivelas'],
#  159.0: ['Maia',
#   'Oeiras',
#   'Porto',
#   'Gondomar',
#   'Lisboa',
#   'Cascais',
#   'Barreiro'],
#  97.0: ['Gondomar', 'Porto', 'Maia', 'Oeiras', 'Seixal'],
#  109.0: ['Gondomar', 'Porto', 'Maia', 'Oeiras'],
#  92.0: ['Gondomar'],
#  150.0: ['Maia',
#   'Porto',
#   'Oeiras',
#   'Gondomar',
#   'Barreiro',
#   'Lisboa',
#   'Seixal'],
#  164.0: ['Porto', 'Maia', 'Gondomar'],
#  143.0: ['Maia',
#   'Porto',
#   'Gondomar',
#   'Seixal',
#   'Sintra',
#   'Barreiro',
#   'Lisboa',
#   'Oeiras',
#   'Matosinhos'],
#  144.0: ['Maia',
#   'Porto',
#   'Gondomar',
#   'Seixal',
#   'Sintra',
#   'Barreiro',
#   'Lisboa',
#   'Oeiras',
#   'Matosinhos'],
#  166.0: ['Barreiro'],
#  22.0: [],
#  24.0: []}

# %%
seniors_df.head(2)
# Out:
#      linkid Region_of_Origin District_of_Origin County_of_Origin  \
# 0  80216810   R1 - AM Lisboa             Lisboa           Lisboa
# 1  80216810   R1 - AM Lisboa             Lisboa           Lisboa
#
#    Average_Daily_SeniorPopulation_Travelling  IDRoute
# 0                                2013.681187      8.0
# 1                                2013.681187     85.0

# %%
set(senior_tim.County_of_Origin)

# %%
senior_tim[]

# %%
busroutes.head(2)

# %%
len(set(busroutes.IDRoute)), len(set(busroutes.linkid))

# %%
len(set(senior_tim.linkid))
